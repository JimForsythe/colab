# %% [markdown]
# <a href="https://colab.research.google.com/github/JimForsythe/colab/blob/main/BQ_Connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from google.colab import auth
auth.authenticate_user()
print('Authenticated')

# %load_ext google.colab.data_table
# Out:
# Authenticated
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
## get data from BigQuery
## set the dataset and table name as test_df

# %%bigquery test_df --project nbcu-ds-sandbox-a-001 
SELECT * FROM 
## change the name of the table below to the name of the table you want to use --- result for save_ab_test_result
nbcu-ds-prod-001.PeacockDataMartProductAnalyticsSilver.Speed_to_Content 
WHERE adobe_date_est = "2023-04-17" LIMIT 1000
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
test_df
# Out:
# ...
#     adobe_date_est                                         session_id  \
# 0       2023-04-17  2322293668478674475265036680440286940312023-04...
# 1       2023-04-17  320003364600642660310606163917201453772762023-...
# 2       2023-04-17  493265051638598224557340994300963721971452023-...
# 3       2023-04-17  43009421622673680807119528223204445601532023-0...
# 4       2023-04-17  28181616621382671092875397276906531164672023-0...
# ..             ...                                                ...
# 995     2023-04-17  22792625827423404426717344565612429764112023-0...
# 996     2023-04-17  386497544255018928665549411226099291412422023-...
# 997     2023-04-17  386497544255018928665549411226099291412422023-...
# 998     2023-04-17  490772475432191896027922692481668655785382023-...
# 999     2023-04-17  41790136820653381502170812913887048995242023-0...
#
#     platform                                    trackingid  \
# 0    android  otazf5cabi8oav0egihhyd1gylrb61q2jcxftsbto9q=
# ...
